# %% [markdown]
# DOMAIN: Smartphone, Electronics
#
# • CONTEXT: India is the second largest market globally for smartphones after China. About 134 million smartphones were sold across India
# in the year 2017 and is estimated to increase to about 442 million in 2022. India ranked second in the average time spent on mobile web by
# smartphone users across Asia Pacific. The combination of very high sales volumes and the average smartphone consumer behaviour has
# made India a very attractive market for foreign vendors. As per Consumer behaviour, 97% of consumers turn to a search engine when they
# are buying a product vs. 15% who turn to social media. If a seller succeeds to publish smartphones based on user’s behaviour/choice at the
# right place, there are 90% chances that user will enquire for the same. This Case Study is targeted to build a recommendation system
# based on individual consumer’s behaviour or choice.
#
# • DATA DESCRIPTION:
#
# • author : name of the person who gave the rating
#
# • country : country the person who gave the rating belongs to
#
# • data : date of the rating
#
# • domain: website from which the rating was taken from
#
# • extract: rating content
#
# • language: language in which the rating was given
#
# • product: name of the product/mobile phone for which the rating was given
#
# • score: average rating for the phone
#
# • score_max: highest rating given for the phone
#
# • source: source from where the rating was taken
#
#
# • PROJECT OBJECTIVE:
#
# We will build a recommendation system using popularity based and collaborative filtering methods to recommend
# mobile phones to a user which are most popular and personalised respectively.

# %%
#1. Import the necessary libraries and read the provided CSVs as a data frame and perform the below steps. [15 Marks]
#A. Merge all the provided CSVs into one dataFrame. [2 Marks]
#B. Explore, understand the Data and share at least 2 observations. [2 Marks]
#C. Round off scores to the nearest integers. [3 Marks]
#D. Check for missing values. Impute the missing values, if any. [2 Marks]
#E. Check for duplicate values and remove them, if any. [2 Marks]
#F. Keep only 1 Million data samples. Use random state=612. [2 Marks]
#G. Drop irrelevant features. Keep features like Author, Product, and Score. [2 Marks]

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from collections import defaultdict
from surprise import SVD
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#did pip install as above getting No module named 'surprise' error.
#!pip install surprise
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from collections import defaultdict
from surprise import SVD
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# from google.colab import drive
# drive.mount('/content/drive')
path1="./Data Set/phone_user_review_file_1.csv" 
file1 = pd.read_csv(path1,encoding='iso-8859-1')

# %%
path2="./Data Set/phone_user_review_file_2.csv" 
file2 = pd.read_csv(path2,encoding='iso-8859-1')

path3="./Data Set/phone_user_review_file_3.csv" 
file3 = pd.read_csv(path3,encoding='iso-8859-1')

path4="./Data Set/phone_user_review_file_4.csv" 
file4 = pd.read_csv(path4,encoding='iso-8859-1')

path5="./Data Set/phone_user_review_file_5.csv" 
file5 = pd.read_csv(path5,encoding='iso-8859-1')

path6="./Data Set/phone_user_review_file_6.csv" 
file6 = pd.read_csv(path6,encoding='iso-8859-1')

# %%
file1.head().T
# Out:
#                                                            0  \
# phone_url                     /cellphones/samsung-galaxy-s8/
# date                                                5/2/2017
# lang                                                      en
# country                                                   us
# source                                      Verizon Wireless
# domain                                   verizonwireless.com
# score                                                   10.0
# score_max                                               10.0
# extract    As a diehard Samsung fan who has had every Sam...
# author                                            CarolAnn35
# product                                    Samsung Galaxy S8
#
#                                                            1  \
# phone_url                     /cellphones/samsung-galaxy-s8/
# date                                               4/28/2017
# ...

# %%
file2.head().T
# Out:
#                                                            0  \
# phone_url                         /cellphones/leagoo-lead-7/
# date                                               4/15/2015
# lang                                                      en
# country                                                   us
# source                                                Amazon
# domain                                            amazon.com
# score                                                    2.0
# score_max                                               10.0
# extract    The telephone headset is of poor quality , not...
# author                                                  luis
# product    Leagoo Lead7 5.0 Inch HD JDI LTPS Screen 3G Sm...
#
#                                                            1  \
# phone_url                         /cellphones/leagoo-lead-7/
# date                                               5/23/2015
# ...

# %%
file3.head().T
# Out:
#                                                            0  \
# phone_url    /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/
# date                                               11/7/2015
# lang                                                      pt
# country                                                   br
# source                                             Submarino
# domain                                      submarino.com.br
# score                                                    6.0
# score_max                                               10.0
# extract    recomendo, eu comprei um, a um ano, e agora co...
# author                                      herlington tesch
# product    Samsung Smartphone Samsung Galaxy S3 Slim G381...
#
#                                                            1  \
# phone_url    /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/
# date                                               10/2/2015
# ...

# %%
file4.head().T
# Out:
#                                                            0  \
# phone_url         /cellphones/samsung-s7262-duos-galaxy-ace/
# date                                               3/11/2015
# lang                                                      en
# country                                                   us
# source                                                Amazon
# domain                                            amazon.com
# score                                                    2.0
# score_max                                               10.0
# extract    was not conpatable with my phone as stated. I ...
# author                                      Frances DeSimone
# product    Samsung Galaxy Star Pro DUOS S7262 Unlocked Ce...
#
#                                                            1  \
# phone_url         /cellphones/samsung-s7262-duos-galaxy-ace/
# date                                              17/11/2015
# ...

# %%
file5.head().T
# Out:
#                                                            0  \
# phone_url                         /cellphones/karbonn-k1616/
# date                                               7/13/2016
# lang                                                      en
# country                                                   in
# source                                            91 Mobiles
# domain                                         91mobiles.com
# score                                                    2.0
# score_max                                               10.0
# extract    I bought 1 month before. currently speaker is ...
# author                                             venkatesh
# product                                        Karbonn K1616
#
#                                                            1  \
# phone_url                         /cellphones/karbonn-k1616/
# date                                               7/13/2016
# ...

# %%
file6.head().T
# Out:
#                                                            0  \
# phone_url             /cellphones/samsung-instinct-sph-m800/
# date                                               9/16/2011
# lang                                                      en
# country                                                   us
# source                                           Phone Arena
# domain                                        phonearena.com
# score                                                    8.0
# score_max                                               10.0
# extract    I've had the phone for awhile and it's a prett...
# author                                            ajabrams95
# product                                  Samsung Instinct HD
#
#                                                            1  \
# phone_url             /cellphones/samsung-instinct-sph-m800/
# date                                               2/13/2014
# ...

# %%
file1.shape
# Out:
# (374910, 11)

# %%
file2.shape
# Out:
# (114925, 11)

# %%
file3.shape
# Out:
# (312961, 11)

# %%
file4.shape
# Out:
# (98284, 11)

# %%
file5.shape
# Out:
# (350216, 11)

# %%
file6.shape
# Out:
# (163837, 11)

# %%
#A. Merge all the provided CSVs into one dataFrame. [2 Marks]
#B. Explore, understand the Data and share at least 2 observations. [2 Marks]
#C. Round off scores to the nearest integers. [3 Marks]
#D. Check for missing values. Impute the missing values, if any. [2 Marks]
#E. Check for duplicate values and remove them, if any. [2 Marks]
#F. Keep only 1 Million data samples. Use random state=612. [2 Marks]
#G. Drop irrelevant features. Keep features like Author, Product, and Score. [2 Marks]
file=pd.concat([file1,file2,file3,file4,file5,file6],axis=0)

# %%
file_copy=file.copy()

# %%
file.info()
#All columns in the final merged dataframe and of object type excep score and score max
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415133 entries, 0 to 163836
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  object
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 129.6+ MB

# %%
file.describe()
#Standard deviation is close to minimum value. mean is between 25% and 75%.
# Out:
#               score  score_max
# count  1.351644e+06  1351644.0
# mean   8.007060e+00       10.0
# std    2.616121e+00        0.0
# min    2.000000e-01       10.0
# 25%    7.200000e+00       10.0
# 50%    9.200000e+00       10.0
# 75%    1.000000e+01       10.0
# max    1.000000e+01       10.0

# %%
#Check for missing values. Impute the missing values, if any. [2 Marks]
file.isnull().values.any()
# Out:
# True

# %%
#Above means there are null values
null_count=file.isnull().sum()
print(null_count)
#column score, score_max,extract,author,product had null values
# Out:
# phone_url        0
# date             0
# lang             0
# country          0
# source           0
# domain           0
# score        63489
# score_max    63489
# extract      19361
# author       63202
# product          1
# dtype: int64

# %%
#filling the missing value with median value (score and score_max)
file=file.fillna(file.median())

# %%
file=file.dropna()
#dropped entries with blank data in extract, author and product columns

# %%
file.isnull().values.any()
# Out:
# False

# %%
#Review if all null values are treated or not
null_count=file.isnull().sum()
print(null_count)
# Out:
# phone_url    0
# date         0
# lang         0
# country      0
# source       0
# domain       0
# score        0
# score_max    0
# extract      0
# author       0
# product      0
# dtype: int64

# %%
#Round off scores to the nearest integers. [3 Marks]
file['score']=file['score'].astype(int)
file['score_max']=file['score_max'].astype(int)
#changed float data type to integer

# %%
file.shape
# Out:
# (1336416, 11)

# %%
#Check for duplicate values and remove them, if any. [2 Marks]
file_duplicate=file.drop_duplicates()

# %%
#Drop irrelevant features. Keep features like Author, Product, and Score. [2 Marks]
#phone_url, date, lang, country, source, domain and extract are not relevant feature. Hence dropping them.
file_duplicate.drop(['phone_url','date','lang','country','source','domain','score_max','extract'],axis=1,inplace=True)

# %%
file_1=file_duplicate.copy()

# %%
file_duplicate.shape
# Out:
# (1331600, 3)

# %%
#Keep only 1 Million data samples. Use random state=612. [2 Marks]
df=file_duplicate.sample(n=1000000,random_state=612)

# %%
#2A. Identify the most rated products. [3 Marks]
df.groupby('product')['score'].mean().sort_values(ascending=False).head()
# Out:
# product
# Smartphone Sony Xperia E1 Desbloqueado Vivo Android 4.3 Tela 4 4GB 3G Wi-Fi CÃ¢mera 3MP - Branco                     10.0
# Samsung Smartphone Samsung Galaxy S5 Desbloqueado Branco Android 4.4.2 4G CÃ¢mera 16 MP MemÃ³ria Interna 16 GB       10.0
# Samsung Smartphone Samsung Galaxy S5 Duos Desbloqueado/ Dual Chip / Branco / 4G / 16 MP / Android 4.4                10.0
# Samsung Smartphone Samsung Galaxy S5 Desbloqueado/ Branco / 4G / 16 MP / Android 4.4.2 / 16 GB / USB 3.0             10.0
# Samsung Smartphone Samsung Galaxy S5 Desbloqueado Vivo Preto Android 4.4.2 4G CÃ¢mera 16 MP MemÃ³ria Interna 16GB    10.0
# Name: score, dtype: float64

# %%
#Product that got most review
df['product'].value_counts().head()
# Out:
# Lenovo Vibe K4 Note (White,16GB)     3908
# Lenovo Vibe K4 Note (Black, 16GB)    3234
# OnePlus 3 (Graphite, 64 GB)          3128
# OnePlus 3 (Soft Gold, 64 GB)         2643
# Huawei P8lite zwart / 16 GB          1994
# Name: product, dtype: int64

# %%
#2B. Identify the users with most number of reviews. [3 Marks]
(df['author'].value_counts()).head()
# Out:
# Amazon Customer    57765
# Cliente Amazon     14564
# e-bit               6309
# Client d'Amazon     5720
# Amazon Kunde        3624
# Name: author, dtype: int64

# %%
#Based on above, maximum review is for Amazon Customers

# %%
# The product that got most number of reviews.
df['product'].value_counts().head()
# Out:
# Lenovo Vibe K4 Note (White,16GB)     3908
# Lenovo Vibe K4 Note (Black, 16GB)    3234
# OnePlus 3 (Graphite, 64 GB)          3128
# OnePlus 3 (Soft Gold, 64 GB)         2643
# Huawei P8lite zwart / 16 GB          1994
# Name: product, dtype: int64

# %%
#Select the data with products having more than 50 ratings and users who have given more than 50 ratings. Report the shape of the finaldataset. [4 Marks]
df_authorGT50rating = pd.DataFrame(columns=['author', 'a_count'])
df_authorGT50rating['author']=df['author'].value_counts().index.tolist() 
df_authorGT50rating['a_count'] = list(df['author'].value_counts() > 50)
df_authorGT50rating
# Out:
#                      author  a_count
# 0           Amazon Customer     True
# 1            Cliente Amazon     True
# 2                     e-bit     True
# 3           Client d'Amazon     True
# 4              Amazon Kunde     True
# ...                     ...      ...
# 619805      Rahul G Satpute    False
# 619806               tayou1    False
# 619807     Stephen Franklin    False
# 619808           al.eliseef    False
# 619809  ALBERT M. MASSILLON    False
#
# [619810 rows x 2 columns]

# %%
# get index names where the value is false
index_names = df_authorGT50rating[ df_authorGT50rating['a_count'] == False ].index 
# drop these false index from dataFrame 
df_authorGT50rating.drop(index_names, inplace = True) 
df_authorGT50rating
# Out:
#               author  a_count
# 0    Amazon Customer     True
# 1     Cliente Amazon     True
# 2              e-bit     True
# 3    Client d'Amazon     True
# 4       Amazon Kunde     True
# ..               ...      ...
# 674            Rohit     True
# 675           mircan     True
# 676             Rose     True
# 677          Dominik     True
# 678           Alexis     True
#
# [679 rows x 2 columns]

# %%
# extracting product that got more than 50 ratings
df_productGT50rating = pd.DataFrame(columns=['product', 'p_count'])
df_productGT50rating['product']=df['product'].value_counts().index.tolist() 
df_productGT50rating['p_count'] = list(df['product'].value_counts() > 50)

# %%
# get index names where the value is false
index_names = df_productGT50rating[ df_productGT50rating['p_count'] == False ].index 
# drop these false index from dataFrame 
df_productGT50rating.drop(index_names, inplace = True) 
df_productGT50rating
# Out:
#                                                 product  p_count
# 0                      Lenovo Vibe K4 Note (White,16GB)     True
# 1                     Lenovo Vibe K4 Note (Black, 16GB)     True
# 2                           OnePlus 3 (Graphite, 64 GB)     True
# 3                          OnePlus 3 (Soft Gold, 64 GB)     True
# 4                           Huawei P8lite zwart / 16 GB     True
# ...                                                 ...      ...
# 4341  Microsoft Nokia Lumia 1320 Smartphone (6 Zoll ...     True
# 4342                         Sony Ericsson W995 Walkman     True
# 4343  Sim Free Apple iPhone SE 16GB Mobile Phone - R...     True
# 4344              SAMSUNG S5830 GALAXY ACE CEP TELEFONU     True
# 4345  Apple iPhone 5 Smartphone d??bloqu?? 3G (4 pou...     True
#
# [4346 rows x 2 columns]

# %%
#Select the data with products having more than 50 ratings and users who have given more than 50 ratings. Report the shape of the finaldataset. 
df_final=df[df['product'].isin(df_productGT50rating['product'])] 
df_final
# Out:
#         score               author  \
# 104246     10               Paul B
# 78693      10               Yuvraj
# 8816        2       Joyce D. Pratt
# 116623     10              David B
# 35333      10            Sebastian
# ...       ...                  ...
# 87173       8               Javier
# 281625      8               Patrix
# 110881      2      Amazon Customer
# 36197      10           majere1975
# 99081      10  ALBERT M. MASSILLON
#
#                                                   product
# 104246  Samsung i897 Captivate Android Smartphone Gala...
# 78693                          Blu Win JR LTE (Grey, 4GB)
# 8816    BLU Vivo XL Smartphone - 5.5" 4G LTE - GSM Unl...
# 116623       Samsung S3350 Chat 335 Sim Free Mobile Phone
# 35333   Samsung E1190 Handy (3,6 cm (1,43 Zoll) Displa...
# ...                                                   ...
# 87173   Huawei Ascend Y330 - Smartphone libre Android ...
# 281625  Huawei Ascend G510 Smartphone Touch, Fotocamer...
# ...

# %%
df_final = df_final[df_final['author'].isin(df_authorGT50rating['author'])]
df_final
# Out:
#         score           author  \
# 35333      10        Sebastian
# 290678      8             sara
# 101404     10   ÐÐ²Ð³ÐµÐ½Ð¸Ð¹
# 223332      8  Amazon Customer
# 361379     10            e-bit
# ...       ...              ...
# 21110       2  Amazon customer
# 321740      8           Qantas
# 269553      9           Capyto
# 87173       8           Javier
# 110881      2  Amazon Customer
#
#                                                   product
# 35333   Samsung E1190 Handy (3,6 cm (1,43 Zoll) Displa...
# 290678  Samsung SM-N910F Galaxy Note 4 Smartphone, 32 ...
# 101404                  Sony Xperia Z1 Compact (Ð»Ð°Ð¹Ð¼)
# 223332  Motorola Moto G 3rd Generation SIM-Free Smartp...
# 361379           Smartphone Motorola Moto G 4 Play XT1603
# ...                                                   ...
# 21110   Tracfone Motorola Moto E Android Prepaid Phone...
# 321740                     Sony Ericsson K810i Cyber-shot
# ...

# %%
df_final.shape
# Out:
# (108983, 3)

# %%
#3. Build a popularity based model and recommend top 5 mobile phones. [5 Marks]

# %%
#Recommending 5 mobile phones based in highest mean score and highest number of ratings
ratings_mean_count = pd.DataFrame(df.groupby('product')['score'].mean()) 
ratings_mean_count['rating_counts'] = pd.DataFrame(df.groupby('product')['score'].count())  
ratings_mean_count.sort_values(by=['score','rating_counts'], ascending=[False,False]).head()
# Out:
#                                                     score  rating_counts
# product
# Samsung Galaxy Note5                                 10.0            144
# Nokia Smartphone Nokia Lumia 520 Desbloqueado O...   10.0            132
# Motorola Smartphone Motorola Moto X Desbloquead...   10.0            131
# Samsung Smartphone Galaxy Win Duos Branco Desbl...   10.0            127
# Motorola Smartphone Motorola Moto G Dual Chip D...   10.0            126

# %%
PopularityBased=df
df
# Out:
#         score               author  \
# 104246     10               Paul B
# 78693      10               Yuvraj
# 109329     10        Pankaj Bhalla
# 64164       6             Bgrazina
# 8816        2       Joyce D. Pratt
# ...       ...                  ...
# 70406       4                Dudls
# 16189       8            Cintaaa__
# 99081      10  ALBERT M. MASSILLON
# 102484      2      Amazon Customer
# 7271        2      Amazon Customer
#
#                                                   product
# 104246  Samsung i897 Captivate Android Smartphone Gala...
# 78693                          Blu Win JR LTE (Grey, 4GB)
# 109329                      Lenovo P780 (Deep Black, 4GB)
# 64164                             Samsung Galaxy XCover 2
# 8816    BLU Vivo XL Smartphone - 5.5" 4G LTE - GSM Unl...
# ...                                                   ...
# 70406                                      Nokia 301 Dual
# 16189                                     LG Viewty KU990
# ...

# %%
#Build a collaborative filtering model using SVD. You can use SVD from surprise or build it from scratch(Note: Incase you’re building it from scratch you
#can limit your data points to 5000 samples if you face memory issues). Build a collaborative filtering model using kNNWithMeans from surprise. You
#can try both user-based and item-based model. [10 Marks]

# %%
columns_header = ['author','product','score']
svd = file_1.reindex(columns=columns_header)
svd_data = svd.sample(n=5000, random_state=612)
reader = Reader(rating_scale=(1,10))
svd_data1 = Dataset.load_from_df(svd_data,reader=reader)

# %%
trainset = svd_data1.build_full_trainset()
trainset.ur
# Out:
# defaultdict(list,
#             {0: [(0, 10.0)],
#              1: [(1, 10.0)],
#              2: [(2, 10.0)],
#              3: [(3, 6.0)],
#              4: [(4, 2.0)],
#              5: [(5, 10.0)],
#              6: [(6, 10.0), (1363, 10.0)],
#              7: [(7, 10.0)],
#              8: [(8, 8.0), (465, 9.0)],
#              9: [(9, 8.0)],
#              10: [(10, 10.0)],
#              11: [(11, 2.0)],
#              12: [(12, 8.0)],
#              13: [(13, 8.0)],
#              14: [(14, 10.0)],
#              15: [(15, 10.0)],
#              16: [(16, 2.0)],
#              17: [(17, 8.0)],
#              18: [(18, 10.0)],
#              19: [(19, 9.0)],
#              20: [(20, 8.0)],
#              21: [(21, 10.0),
#               (909, 9.0),
#               (2202, 6.0),
#               (2551, 10.0),
#               (3378, 9.0),
#               (3614, 10.0)],
#              22: [(22, 2.0)],
#              23: [(23, 10.0)],
#              24: [(24, 8.0)],
# ...

# %%
algo = SVD()
algo.fit(trainset)

# %%
testset = trainset.build_anti_testset()

# %%
predictions = algo.test(testset)
predictions
#below shows the predicted items and their estimated ratings for test user.
# Out:
# [Prediction(uid='Paul B', iid='Blu Win JR LTE (Grey, 4GB)', r_ui=8.0086, est=8.417217175658973, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='Lenovo P780 (Deep Black, 4GB)', r_ui=8.0086, est=8.36660623311974, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='Samsung Galaxy XCover 2', r_ui=8.0086, est=7.988015161634378, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='BLU Vivo XL Smartphone - 5.5" 4G LTE - GSM Unlocked - Solid Gold', r_ui=8.0086, est=8.226591315952662, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='Samsung S3350 Chat 335 Sim Free Mobile Phone', r_ui=8.0086, est=8.343619346493327, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='Samsung E1190 Handy (3,6 cm (1,43 Zoll) Display, Dual-Band) titan gray', r_ui=8.0086, est=8.469833530220368, details={'was_impossible': False}),
# ...

# %%
#8. Try and recommend top 5 products for test users. [5 Marks]
#Write function to predict top 5
def get_top_n(predictions, n=5):
# First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n
top_n = get_top_n(predictions, n=5)
top_n
# Out:
# defaultdict(list,
#             {'Paul B': [('Huawei P8 lite Smartphone, Display 5.0" IPS, Dual Sim, Processore Octa-Core, Memoria 16 GB, Fotocamera 13 MP, Android 5.0, Bianco',
#                9.159963540698511),
#               ('Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]',
#                9.097625546734326),
#               ('Huawei Ascend Y530 Smartphone (4,5 Zoll (11,4 cm) Touch-Display, 4 GB Speicher, Android 4.3) weiÃ\x9f',
#                8.96932119756835),
#               ('OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)',
#                8.851728756641451),
#               ('Lenovo Motorola Moto G 4G (2 Generazione) Smartphone, Display 5 Pollici, LTE, Fotocamera 8 MP, Memoria 8 GB, Android 5 Lollipop, Nero [Italia]',
#                8.844095953180819)],
# ...

# %%
#5. Evaluate the collaborative model. Print RMSE value. [2 Marks]
print("SVD Model : Test Set")
accuracy.rmse(predictions, verbose=True)
# Out:
# SVD Model : Test Set
# RMSE: 0.3368
# 0.33677888514210347

# %%
cross_validate(algo, svd_data1, measures=['RMSE'], cv=3, verbose=False)
# Out:
# {'test_rmse': array([2.58638004, 2.52381781, 2.64495765]),
#  'fit_time': (0.26677799224853516, 0.3037095069885254, 0.2941005229949951),
#  'test_time': (0.028439044952392578, 0.09293150901794434, 0.01505589485168457)}

# %%
#Based on above, it shows that RMSE of SVD model is lower than for cross validation

# %%
def get_Iu(uid):
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError:
        return 0
    
def get_Ui(iid):
    try: 
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:
        return 0
bf = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])
bf['Iu'] = bf.uid.apply(get_Iu)
bf['Ui'] = bf.iid.apply(get_Ui)
bf['err'] = abs(bf.est - bf.rui)
best_predictions = bf.sort_values(by='err')[:10]
worst_predictions = bf.sort_values(by='err')[-10:]
best_predictions
worst_predictions

# %%
#My system crashed 1st time with above statement, Again doing

# %%
#kNNWithMeans from surprise using Item based model
#4: You can try both user-based and item-based model.
reader=Reader(rating_scale=(1, 10))
data_I = Dataset.load_from_df(svd_data,reader = reader)
trainset_KNN, testset_KNN = train_test_split(data_I, test_size=.15)
algo = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset_KNN)
# run the  model against the testset
testset_pred_KNN = algo.test(testset_KNN)
testset_pred_KNN
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# [Prediction(uid='Markozawr', iid='Samsung C3510', r_ui=8.0, est=8.049411764705882, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð\x9fÐ°Ñ\x88Ð°', iid='Samsung S8500 Wave (2Gb)', r_ui=10.0, est=8.049411764705882, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Niels van Beek', iid='Sony Xperia Z5 goud / 32 GB', r_ui=9.0, est=8.049411764705882, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Marco', iid='Emporia Click - MÃ³vil libre (pantalla 2.2", cÃ¡mara 0.3 Mp, 2 MB), Negro', r_ui=10.0, est=8.049411764705882, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...

# %%
# get RMSE
print("Item-based Model : Test Set")
accuracy.rmse(testset_pred_KNN, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 2.8188
# 2.818755644633794

# %%
#collaborative filter model with kNN using user based model
reader = Reader(rating_scale=(1, 10))
data_User = Dataset.load_from_df(svd_data,reader = reader)
trainset_user, testset_user = train_test_split(data_User, test_size=.15)
algo = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
algo.fit(trainset_user)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# Find business scenario where we can use it
#This can be used to query prediction for specific user
userid = 'Frances DeSimone'  # raw user id
itemid = 'Samsung Galaxy Star Pro DUOS S7262 Unlocked Ce.'  # raw item id
pred = algo.predict(userid, itemid, verbose=True)
# Out:
# user: Frances DeSimone item: Samsung Galaxy Star Pro DUOS S7262 Unlocked Ce. r_ui = None   est = 8.01   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}

# %%
#model is unable to predict for above user and product
test_pred_user = algo.test(testset_user)
test_pred_user
# Out:
# [Prediction(uid='Muiambo', iid='Samsung Galaxy Xcover', r_ui=2.0, est=8.009882352941176, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Xenonz', iid='HTC One X', r_ui=10.0, est=8.009882352941176, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='TheKewlOne17', iid='Samsung Tracfone Samsung T155g No Contract Cell Phone - Black (Prepaid Phone NOT Unlocked )', r_ui=2.0, est=8.009882352941176, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='michele cotton', iid='Apple iPhone 5C Factory Unlocked Cellphone, 8GB, White', r_ui=2.0, est=8.009882352941176, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='bjsiddiqui', iid='Samsung GALAXY S Advance', r_ui=10.0, est=8.009882352941176, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...

# %%
#5. Evaluate the collaborative model. Print RMSE value. [2 Marks]
print("User-based Model : Test Set")
accuracy.rmse(test_pred_user, verbose=True)
# Out:
# User-based Model : Test Set
# RMSE: 2.6884
# 2.6883995110953762

# %%
d_df = df
df.shape
# Out:
# (1000000, 3)

# %%
cross_validate(algo,data_User, measures=['RMSE'], cv=3, verbose=False)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# {'test_rmse': array([2.63582201, 2.61922665, 2.58649269]),
#  'fit_time': (0.3114128112792969, 0.3190317153930664, 0.551964282989502),
#  'test_time': (0.03026866912841797, 0.03669404983520508, 0.07228422164916992)}

# %%
#7. Report your findings and inferences. [2 Marks]

# %%
#Ans: Samsung Galaxy Note5 is the most popular product Amazon Customer is the most active author who writes reviews. Lenovo Vibe K4 Note (White,16GB) was rated by most of the authors CV rmse was 2.5

# %%
#10. In what business scenario you should use popularity based Recommendation Systems ? [2 Marks]
#ANS: Popularity based recommendation system focuses on the popularity,trends and frequency counts of which items were most purchased.
#It basically uses the items which are in trend right now. For example, if any product which is usually bought by every new user then there are chances that it may suggest that item to the user who just signed up.

# %%
#11. In what business scenario you should use CF based Recommendation Systems ? [2 Marks]
#Ans. Collaborative Filtering is used to building intelligent recommender systems that can learn to give better recommendations as more information about users is collected. 
#Most websites like Amazon, YouTube, and Netflix use collaborative filtering as a part of their sophisticated recommendation systems. 
#We can use this technique to build recommenders that give suggestions to a user on the basis of the likes and dislikes of similar users.This is personalized one.

# %%
#12: What other possible methods can you think of which can further improve the recommendation for different users ? [2 Marks]
#Collaborative recommendation, Content-based recommendation, Hybrid recommendation systems can be used
